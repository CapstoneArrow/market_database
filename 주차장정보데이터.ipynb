# %%
import pandas as pd

# %%
df = pd.read_csv('/content/한국국토정보공사 주차장 정보 DB_20230829.csv',encoding='cp949')

# %%
df
# Out:
#          본부명       부서명                                     주소    우편번호  \
# 0         본사  한국국토정보공사               전라북도 전주시 덕진구 기지로 120(중동)  548-70
# 1    국토정보교육원   국토정보교육원          충청남도 공주시 사곡면 연수단지길 182국토정보교육원  325-22
# 2    공간정보연구원   공간정보연구원  전라북도 완주군 이서면 지사제2로 42한국국토정보공사 공간정보연구원  553-65
# 3     서울지역본부    서울지역본부                 서울특별시 강남구 언주로 703(논현동)  060-53
# 4     서울지역본부    서울중부지사       서울특별시 성북구 안암동1가 고려대로7다길 8(안암동1가)  028-50
# ..       ...       ...                                    ...     ...
# 174   경남지역본부      함양지사      경상남도 함양군 함양읍 함양남서로 1219(백연리460-4)  500-43
# 175   경남지역본부      거창지사                     경상남도 거창군 거창읍 중앙로 4  501-40
# 176   경남지역본부      합천지사            경상남도 합천군 합천읍 동서로 141-4351-6  502-31
# 177   제주지역본부    제주지역본부                   제주특별자치도 제주시 신대로 118층  631-23
# 178   제주지역본부     서귀포지사                   제주특별자치도 서귀포시 서호중로 71  635-68
#
#              전화번호     주차장 운영시간 주차장 이용료                        기타
# ...

# %%
af = df.drop(['본부명','부서명','기타'],axis=1)

# %%
af
# Out:
#                                         주소    우편번호          전화번호     주차장 운영시간  \
# 0                 전라북도 전주시 덕진구 기지로 120(중동)  548-70  063-713-1800  09:00~18:00
# 1            충청남도 공주시 사곡면 연수단지길 182국토정보교육원  325-22  041-401-0200  09:00~18:00
# 2    전라북도 완주군 이서면 지사제2로 42한국국토정보공사 공간정보연구원  553-65  063-710-0300  09:00~18:00
# 3                   서울특별시 강남구 언주로 703(논현동)  060-53  02-6937-2001  09:00~18:00
# 4         서울특별시 성북구 안암동1가 고려대로7다길 8(안암동1가)  028-50  02-6937-2330  09:00~18:00
# ..                                     ...     ...           ...          ...
# 174      경상남도 함양군 함양읍 함양남서로 1219(백연리460-4)  500-43  055-820-5880  09:00~18:00
# 175                     경상남도 거창군 거창읍 중앙로 4  501-40  055-808-5650  09:00~18:00
# 176            경상남도 합천군 합천읍 동서로 141-4351-6  502-31  055-816-8770  09:00~18:00
# 177                   제주특별자치도 제주시 신대로 118층  631-23  064-909-3300  09:00~18:00
# 178                   제주특별자치도 서귀포시 서호중로 71  635-68  064-801-6730  09:00~18:00
#
#     주차장 이용료
# 0        무료
# ...

# %%
af.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   주소        179 non-null    object
#  1   우편번호      179 non-null    object
#  2   전화번호      179 non-null    object
#  3   주차장 운영시간  179 non-null    object
#  4   주차장 이용료   179 non-null    object
# dtypes: object(5)
# memory usage: 7.1+ KB

# %%
af.to_csv('주차장정보데이터.csv')
