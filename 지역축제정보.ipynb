# %%
import pandas as pd

# %%
df = pd.read_excel('/content/2024년 지역축제 개최계획(수정).xlsx','세부현황')

# %%
df.head(5)
# Out:
#    Unnamed: 0        Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN               NaN        NaN        NaN        NaN        NaN
# 1         NaN  2024년 지역축제 개최 계획        NaN        NaN        NaN        NaN
# 2         NaN               NaN        NaN        NaN        NaN        NaN
# 3         NaN                연번  광역자치\n단체명  기초자치\n단체명        축제명       축제유형
# 4         NaN               NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 16  Unnamed: 17  \
# 0        NaN        NaN        NaN          NaN  ...         NaN          NaN
# 1        NaN        NaN        NaN          NaN  ...         NaN          NaN
# 2        NaN        NaN        NaN          NaN  ...         NaN          NaN
# 3       개최기간       개최장소       개최방식  최초\n개최년도(년)  ...         NaN  전담조직(축제사무국)
# 4        NaN        NaN        NaN          NaN  ...      외국인(명)        전담조직명
#
# ...

# %%
df.iloc[5:,1:]
# Out:
#      Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  Unnamed: 5  \
# 5             1         서울          -               NaN        문화예술
# 6             2         서울          -          서울뮤직페스티벌        문화예술
# 7             3         서울          -            서울국악축제        전통역사
# 8             4         서울          -        서울페스타 2024        문화예술
# 9             5         서울          -       서울 바비큐 페스티벌          기타
# ...         ...        ...        ...               ...         ...
# 1170       1166         제주       서귀포시      제19회 중문칠선녀축제  기타(주민화합 등)
# 1171       1167         제주          -    제24회 최남단 방어 축제         특산물
# 1172       1168         제주       서귀포시  제2회 대정 동일 해넘이 축제    기타(주민화합)
# 1173       1169         제주       서귀포시  성산읍 찾아가는 문화예술콘서트        문화예술
# 1174       1170         제주       서귀포시  제6회 대정읍청소년드림페스티벌    기타(주민화합)
#
#          Unnamed: 6           Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# ...

# %%
df.rename(columns={'번호':'연번'}, inplace=True)
df.rename(columns={'Unnamed: 2':'광역자치단체명'}, inplace=True)
df.rename(columns={'Unnamed: 3':'기초자치단체명'}, inplace=True)
df.rename(columns={'Unnamed: 4':'축제명'}, inplace=True)
df.rename(columns={'Unnamed: 5':'축제유형'}, inplace=True)
df.rename(columns={'Unnamed: 6':'개최기간'}, inplace=True)
df.rename(columns={'Unnamed: 7':'개최장소'}, inplace=True)
df.rename(columns={'Unnamed: 8':'개최방식'}, inplace=True)
df.rename(columns={'Unnamed: 9':'최초개최년도'}, inplace=True)
df.rename(columns={'Unnamed: 10':'합계'}, inplace=True)
df.rename(columns={'Unnamed: 11':'국비'}, inplace=True)
df.rename(columns={'Unnamed: 12':'지방비'}, inplace=True)
df.rename(columns={'Unnamed: 13':'기타(민간,자부담 등)'}, inplace=True)
df.rename(columns={'Unnamed: 14':'합계'}, inplace=True)
df.rename(columns={'Unnamed: 15':'내국인(명)'}, inplace=True)
df.rename(columns={'Unnamed: 16':'외국인(명)'}, inplace=True)
df.rename(columns={'Unnamed: 17':'전담조직명'}, inplace=True)
df.rename(columns={'Unnamed: 18':'조직형태'}, inplace=True)
df.rename(columns={'Unnamed: 19':'설립근거'}, inplace=True)
df.rename(columns={'Unnamed: 20':'국비지원부처명'}, inplace=True)
df.rename(columns={'Unnamed: 21':'기관명'}, inplace=True)
df.rename(columns={'Unnamed: 22':'부서명'}, inplace=True)
df.rename(columns={'Unnamed: 23':'직급/직책'}, inplace=True)
df.rename(columns={'Unnamed: 24':'성명'}, inplace=True)
df.rename(columns={'Unnamed: 25':'연락처'}, inplace=True)

# %%
df.iloc[5:10,1:]
# Out:
#   Unnamed: 1 광역자치단체명 기초자치단체명          축제명  축제유형       개최기간  \
# 5          1      서울       -          NaN  문화예술  5.25~5.26
# 6          2      서울       -     서울뮤직페스티벌  문화예술  9.27~9.29
# 7          3      서울       -       서울국악축제  전통역사       9월 중
# 8          4      서울       -   서울페스타 2024  문화예술  5.1.~5.6.
# 9          5      서울       -  서울 바비큐 페스티벌    기타  5.4.~5.5.
#
#                   개최장소 개최방식 최초개최년도    합계  ...  외국인(명)      전담조직명  조직형태  \
# 5                  노들섬   대면   1999   564  ...     미집계  서울시 문화예술과   지자체
# 6                  노들섬   대면   2019  1062  ...     500  서울시 문화예술과   지자체
# 7                   미정   대면   2019   207  ...     미집계  서울시 문화예술과   지자체
# 8  서울광장, 광화문광장 등 서울 전역   대면   2022  2115  ...  242330     서울관광재단  재단법인
# 9                 노을공원   대면   2024   350  ...       0     서울관광재단  재단법인
#
#                           설립근거 국비지원부처명   기관명    부서명 직급/직책   성명           연락처
# 5                            -    해당없음  서울시청  문화예술과   주무관  이지선  02-2133-2571
# ...

# %%
af = df.iloc[5:,1:]

# %%
af
# Out:
#      Unnamed: 1 광역자치단체명 기초자치단체명               축제명        축제유형           개최기간  \
# 5             1      서울       -               NaN        문화예술      5.25~5.26
# 6             2      서울       -          서울뮤직페스티벌        문화예술      9.27~9.29
# 7             3      서울       -            서울국악축제        전통역사           9월 중
# 8             4      서울       -        서울페스타 2024        문화예술      5.1.~5.6.
# 9             5      서울       -       서울 바비큐 페스티벌          기타      5.4.~5.5.
# ...         ...     ...     ...               ...         ...            ...
# 1170       1166      제주    서귀포시      제19회 중문칠선녀축제  기타(주민화합 등)   10월~11월 중 2일
# 1171       1167      제주       -    제24회 최남단 방어 축제         특산물       11월중(예정)
# 1172       1168      제주    서귀포시  제2회 대정 동일 해넘이 축제    기타(주민화합)  12.30.~12.31.
# 1173       1169      제주    서귀포시  성산읍 찾아가는 문화예술콘서트        문화예술             미정
# 1174       1170      제주    서귀포시  제6회 대정읍청소년드림페스티벌    기타(주민화합)             미정
#
# ...

# %%
af.drop(['합계','국비','지방비','설립근거','내국인(명)','외국인(명)','조직형태','최초개최년도','국비지원부처명'], axis=1)
# Out:
#      Unnamed: 1 광역자치단체명 기초자치단체명               축제명        축제유형           개최기간  \
# 5             1      서울       -               NaN        문화예술      5.25~5.26
# 6             2      서울       -          서울뮤직페스티벌        문화예술      9.27~9.29
# 7             3      서울       -            서울국악축제        전통역사           9월 중
# 8             4      서울       -        서울페스타 2024        문화예술      5.1.~5.6.
# 9             5      서울       -       서울 바비큐 페스티벌          기타      5.4.~5.5.
# ...         ...     ...     ...               ...         ...            ...
# 1170       1166      제주    서귀포시      제19회 중문칠선녀축제  기타(주민화합 등)   10월~11월 중 2일
# 1171       1167      제주       -    제24회 최남단 방어 축제         특산물       11월중(예정)
# 1172       1168      제주    서귀포시  제2회 대정 동일 해넘이 축제    기타(주민화합)  12.30.~12.31.
# 1173       1169      제주    서귀포시  성산읍 찾아가는 문화예술콘서트        문화예술             미정
# 1174       1170      제주    서귀포시  제6회 대정읍청소년드림페스티벌    기타(주민화합)             미정
#
# ...

# %%
af['기타(민간,자부담 등)'] = af['기타(민간,자부담 등)'].str.strip()

# %%
cf = af.drop(['합계','국비','지방비','설립근거','내국인(명)','외국인(명)','조직형태','최초개최년도','국비지원부처명','기타(민간,자부담 등)'], axis=1)

# %%
cf
# Out:
#      Unnamed: 1 광역자치단체명 기초자치단체명               축제명        축제유형           개최기간  \
# 5             1      서울       -               NaN        문화예술      5.25~5.26
# 6             2      서울       -          서울뮤직페스티벌        문화예술      9.27~9.29
# 7             3      서울       -            서울국악축제        전통역사           9월 중
# 8             4      서울       -        서울페스타 2024        문화예술      5.1.~5.6.
# 9             5      서울       -       서울 바비큐 페스티벌          기타      5.4.~5.5.
# ...         ...     ...     ...               ...         ...            ...
# 1170       1166      제주    서귀포시      제19회 중문칠선녀축제  기타(주민화합 등)   10월~11월 중 2일
# 1171       1167      제주       -    제24회 최남단 방어 축제         특산물       11월중(예정)
# 1172       1168      제주    서귀포시  제2회 대정 동일 해넘이 축제    기타(주민화합)  12.30.~12.31.
# 1173       1169      제주    서귀포시  성산읍 찾아가는 문화예술콘서트        문화예술             미정
# 1174       1170      제주    서귀포시  제6회 대정읍청소년드림페스티벌    기타(주민화합)             미정
#
# ...

# %%
cf.rename(columns={'Unnamed: 1':'연번'}, inplace=True)

# %%
cf
# Out:
#         연번 광역자치단체명 기초자치단체명               축제명        축제유형           개최기간  \
# 5        1      서울       -               NaN        문화예술      5.25~5.26
# 6        2      서울       -          서울뮤직페스티벌        문화예술      9.27~9.29
# 7        3      서울       -            서울국악축제        전통역사           9월 중
# 8        4      서울       -        서울페스타 2024        문화예술      5.1.~5.6.
# 9        5      서울       -       서울 바비큐 페스티벌          기타      5.4.~5.5.
# ...    ...     ...     ...               ...         ...            ...
# 1170  1166      제주    서귀포시      제19회 중문칠선녀축제  기타(주민화합 등)   10월~11월 중 2일
# 1171  1167      제주       -    제24회 최남단 방어 축제         특산물       11월중(예정)
# 1172  1168      제주    서귀포시  제2회 대정 동일 해넘이 축제    기타(주민화합)  12.30.~12.31.
# 1173  1169      제주    서귀포시  성산읍 찾아가는 문화예술콘서트        문화예술             미정
# 1174  1170      제주    서귀포시  제6회 대정읍청소년드림페스티벌    기타(주민화합)             미정
#
#                      개최장소 개최방식           전담조직명       기관명    부서명 직급/직책   성명  \
# ...

# %%
ff = cf.drop(['전담조직명','기관명'],axis=1)

# %%
ff.loc[5,'축제명'] = '서울드럼페스티벌'

# %%
ff
# Out:
#         연번 광역자치단체명 기초자치단체명               축제명        축제유형           개최기간  \
# 5        1      서울       -          서울드럼페스티벌        문화예술      5.25~5.26
# 6        2      서울       -          서울뮤직페스티벌        문화예술      9.27~9.29
# 7        3      서울       -            서울국악축제        전통역사           9월 중
# 8        4      서울       -        서울페스타 2024        문화예술      5.1.~5.6.
# 9        5      서울       -       서울 바비큐 페스티벌          기타      5.4.~5.5.
# ...    ...     ...     ...               ...         ...            ...
# 1170  1166      제주    서귀포시      제19회 중문칠선녀축제  기타(주민화합 등)   10월~11월 중 2일
# 1171  1167      제주       -    제24회 최남단 방어 축제         특산물       11월중(예정)
# 1172  1168      제주    서귀포시  제2회 대정 동일 해넘이 축제    기타(주민화합)  12.30.~12.31.
# 1173  1169      제주    서귀포시  성산읍 찾아가는 문화예술콘서트        문화예술             미정
# 1174  1170      제주    서귀포시  제6회 대정읍청소년드림페스티벌    기타(주민화합)             미정
#
#                      개최장소 개최방식    부서명 직급/직책   성명           연락처
# ...

# %%
gf = ff.replace(to_replace='-',value='미정')

# %%
gf.head(10)
# Out:
#     연번 광역자치단체명 기초자치단체명                      축제명        축제유형  \
# 5    1      서울      미정                 서울드럼페스티벌        문화예술
# 6    2      서울      미정                 서울뮤직페스티벌        문화예술
# 7    3      서울      미정                   서울국악축제        전통역사
# 8    4      서울      미정               서울페스타 2024        문화예술
# 9    5      서울      미정              서울 바비큐 페스티벌          기타
# 10   6      서울      미정  2024 한강 불빛 공연(드론 라이트 쇼)        문화예술
# 11   7      서울      미정      2024년 추석 농수특산물 서울장터         특산물
# 12   8      서울      미정                   한강페스티벌  문화예술, 생태자연
# 13   9      서울      미정            2024 책읽는 한강공원        문화예술
# 14  10      서울      미정             제18회 서울안전한마당        안전문화
#
#                                                  개최기간                 개최장소  \
# 5                                           5.25~5.26                  노들섬
# 6                                           9.27~9.29                  노들섬
# 7                                                9월 중                   미정
# ...

# %%
gf.to_csv("지역축제정보수정본2.csv")
