# %%
from PIL import Image

# %%
image = Image.open('/content/1.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=740x555>

# %%
img = image_resize = image.resize((300,300))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
img.save('장성중앙시장.jpg')
